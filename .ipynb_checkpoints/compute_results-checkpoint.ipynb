# %%
import os
import csv
from collections import defaultdict
import pandas as pd
from pandas_style import *
from constants import *

event_files = os.listdir("./results")

# Remove system file(s)
if ".DS_Store" in event_files:
    event_files.remove(".DS_Store")

# Sort events chronologically based on file creation times
event_times = []
for event_file in event_files:
    event_times.append(os.path.getmtime("./results/" + event_file))
event_files = [x for _,x in sorted(zip(event_times, event_files))]
    
# Get results for events
events = []
players = []
for event_file in event_files:
    with open("./results/" + event_file, mode='r', errors='ignore') as f:
        csv_reader = csv.DictReader(f)
        event_results = {}
        for row in csv_reader:
            # Add user-score pair to event container
            event_results[row["USER"]] = row["WAID"]
            # Also make sure we have a complete list of all players
            if row["USER"] not in players:
                players.append(row["USER"])
        # Append this event to the global container
        events.append(event_results)

# Get score for each event
score = defaultdict(list)
for event in events:
    for player in players:
        # If player missed this event, add 0
        if player not in event.keys():
            score[player] += [0.0]
        else:
            score[player] += [float(event[player])]

# %% [markdown]
# ### Output Table

# %%
# Finally, let's make the results in a nice table format
event_names = [e[:-4].replace("_", " ") for e in event_files]
# Make a Pandas dataframe
df = pd.DataFrame.from_dict(score, orient='index', columns=event_names)
# Add a sum & sort
df.loc[:,'Total'] = df.sum(axis=1)
df = df.sort_values(by='Total', ascending=False)
pd.set_option('precision', 4)
# Add stylings
df = df.style.\
    applymap(color_negative_red).\
    apply(highlight_event_winner).\
    applymap(bold, subset=pd.IndexSlice[:, 'Total'])
#df.style.set_precision(precision=2)



# Display in the notebook
df
# Out:
# <style  type="text/css" >
#     #T_3f6abb0c_987f_11ea_9f37_1065301e6a96row0_col0 {
#             color:  black;
#             background-color:  gold;
#         }    #T_3f6abb0c_987f_11ea_9f37_1065301e6a96row0_col1 {
#             color:  black;
#             background-color:  gold;
#         }    #T_3f6abb0c_987f_11ea_9f37_1065301e6a96row0_col2 {
#             color:  black;
#             : ;
#         }    #T_3f6abb0c_987f_11ea_9f37_1065301e6a96row0_col3 {
#             color:  black;
#             : ;
#         }    #T_3f6abb0c_987f_11ea_9f37_1065301e6a96row0_col4 {
#             color:  black;
#             background-color:  gold;
#         }    #T_3f6abb0c_987f_11ea_9f37_1065301e6a96row0_col5 {
#             color:  black;
#             : ;
#         }    #T_3f6abb0c_987f_11ea_9f37_1065301e6a96row0_col6 {
#             color:  black;
#             background-color:  gold;
#         }    #T_3f6abb0c_987f_11ea_9f37_1065301e6a96row0_col7 {
#             color:  black;
#             background-color:  gold;
#         }    #T_3f6abb0c_987f_11ea_9f37_1065301e6a96row0_col8 {
#             color:  black;
#             : ;
#         }    #T_3f6abb0c_987f_11ea_9f37_1065301e6a96row0_col9 {
#             color:  black;
#             : ;
#         }    #T_3f6abb0c_987f_11ea_9f37_1065301e6a96row0_col10 {
#             color:  black;
#             : ;
#         }    #T_3f6abb0c_987f_11ea_9f37_1065301e6a96row0_col11 {
#             color:  black;
#             : ;
#         }    #T_3f6abb0c_987f_11ea_9f37_1065301e6a96row0_col12 {
#             color:  black;
#             : ;
#         }    #T_3f6abb0c_987f_11ea_9f37_1065301e6a96row0_col13 {
#             color:  black;
#             : ;
#         }    #T_3f6abb0c_987f_11ea_9f37_1065301e6a96row0_col14 {
#             color:  black;
#             background-color:  gold;
#         }    #T_3f6abb0c_987f_11ea_9f37_1065301e6a96row0_col15 {
#             color:  black;
#             : ;
#         }    #T_3f6abb0c_987f_11ea_9f37_1065301e6a96row0_col16 {
#             color:  black;
#             : ;
#         }    #T_3f6abb0c_987f_11ea_9f37_1065301e6a96row0_col17 {
#             color:  black;
#             : ;
#         }    #T_3f6abb0c_987f_11ea_9f37_1065301e6a96row0_col18 {
#             color:  black;
#             : ;
#         }    #T_3f6abb0c_987f_11ea_9f37_1065301e6a96row0_col19 {
#             color:  black;
#             : ;
#         }    #T_3f6abb0c_987f_11ea_9f37_1065301e6a96row0_col20 {
#             color:  black;
#             background-color:  gold;
#             font-weight:  bold;
#         }    #T_3f6abb0c_987f_11ea_9f37_1065301e6a96row1_col0 {
#             color:  black;
#             : ;
#         }    #T_3f6abb0c_987f_11ea_9f37_1065301e6a96row1_col1 {
#             color:  black;
#             : ;
#         }    #T_3f6abb0c_987f_11ea_9f37_1065301e6a96row1_col2 {
#             color:  black;
#             background-color:  gold;
#         }    #T_3f6abb0c_987f_11ea_9f37_1065301e6a96row1_col3 {
#             color:  red;
#             : ;
#         }    #T_3f6abb0c_987f_11ea_9f37_1065301e6a96row1_col4 {
#             color:  black;
#             : ;
#         }    #T_3f6abb0c_987f_11ea_9f37_1065301e6a96row1_col5 {
#             color:  black;
#             : ;
#         }    #T_3f6abb0c_987f_11ea_9f37_1065301e6a96row1_col6 {
#             color:  black;
#             : ;
#         }    #T_3f6abb0c_987f_11ea_9f37_1065301e6a96row1_col7 {
#             color:  black;
#             : ;
#         }    #T_3f6abb0c_987f_11ea_9f37_1065301e6a96row1_col8 {
#             color:  black;
#             : ;
#         }    #T_3f6abb0c_987f_11ea_9f37_1065301e6a96row1_col9 {
#             color:  black;
#             background-color:  gold;
#         }    #T_3f6abb0c_987f_11ea_9f37_1065301e6a96row1_col10 {
#             color:  black;
#             : ;
#         }    #T_3f6abb0c_987f_11ea_9f37_1065301e6a96row1_col11 {
#             color:  black;
#             background-color:  gold;
#         }    #T_3f6abb0c_987f_11ea_9f37_1065301e6a96row1_col12 {
#             color:  black;
#             : ;
#         }    #T_3f6abb0c_987f_11ea_9f37_1065301e6a96row1_col13 {
#             color:  black;
#             : ;
#         }    #T_3f6abb0c_987f_11ea_9f37_1065301e6a96row1_col14 {
#             color:  black;
#             : ;
#         }    #T_3f6abb0c_987f_11ea_9f37_1065301e6a96row1_col15 {
#             color:  black;
#             : ;
#         }    #T_3f6abb0c_987f_11ea_9f37_1065301e6a96row1_col16 {
#             color:  black;
#             : ;
#         }    #T_3f6abb0c_987f_11ea_9f37_1065301e6a96row1_col17 {
#             color:  black;
#             : ;
#         }    #T_3f6abb0c_987f_11ea_9f37_1065301e6a96row1_col18 {
#             color:  black;
#             : ;
#         }    #T_3f6abb0c_987f_11ea_9f37_1065301e6a96row1_col19 {
#             color:  black;
#             background-color:  gold;
#         }    #T_3f6abb0c_987f_11ea_9f37_1065301e6a96row1_col20 {
#             color:  black;
#             : ;
#             font-weight:  bold;
#         }    #T_3f6abb0c_987f_11ea_9f37_1065301e6a96row2_col0 {
#             color:  black;
#             : ;
#         }    #T_3f6abb0c_987f_11ea_9f37_1065301e6a96row2_col1 {
#             color:  black;
#             : ;
#         }    #T_3f6abb0c_987f_11ea_9f37_1065301e6a96row2_col2 {
#             color:  black;
#             : ;
#         }    #T_3f6abb0c_987f_11ea_9f37_1065301e6a96row2_col3 {
#             color:  black;
#             : ;
#         }    #T_3f6abb0c_987f_11ea_9f37_1065301e6a96row2_col4 {
#             color:  black;
#             : ;
#         }    #T_3f6abb0c_987f_11ea_9f37_1065301e6a96row2_col5 {
#             color:  black;
#             : ;
#         }    #T_3f6abb0c_987f_11ea_9f37_1065301e6a96row2_col6 {
#             color:  black;
#             : ;
#         }    #T_3f6abb0c_987f_11ea_9f37_1065301e6a96row2_col7 {
#             color:  black;
#             : ;
#         }    #T_3f6abb0c_987f_11ea_9f37_1065301e6a96row2_col8 {
#             color:  black;
#             : ;
#         }    #T_3f6abb0c_987f_11ea_9f37_1065301e6a96row2_col9 {
#             color:  black;
#             : ;
#         }    #T_3f6abb0c_987f_11ea_9f37_1065301e6a96row2_col10 {
#             color:  black;
#             : ;
#         }    #T_3f6abb0c_987f_11ea_9f37_1065301e6a96row2_col11 {
#             color:  black;
#             : ;
#         }    #T_3f6abb0c_987f_11ea_9f37_1065301e6a96row2_col12 {
#             color:  black;
#             : ;
#         }    #T_3f6abb0c_987f_11ea_9f37_1065301e6a96row2_col13 {
#             color:  black;
#             : ;
#         }    #T_3f6abb0c_987f_11ea_9f37_1065301e6a96row2_col14 {
#             color:  black;
#             : ;
#         }    #T_3f6abb0c_987f_11ea_9f37_1065301e6a96row2_col15 {
#             color:  black;
#             : ;
#         }    #T_3f6abb0c_987f_11ea_9f37_1065301e6a96row2_col16 {
#             color:  black;
#             : ;
#         }    #T_3f6abb0c_987f_11ea_9f37_1065301e6a96row2_col17 {
#             color:  black;
#             background-color:  gold;
#         }    #T_3f6abb0c_987f_11ea_9f37_1065301e6a96row2_col18 {
#             color:  black;
#             background-color:  gold;
#         }    #T_3f6abb0c_987f_11ea_9f37_1065301e6a96row2_col19 {
#             color:  black;
#             : ;
#         }    #T_3f6abb0c_987f_11ea_9f37_1065301e6a96row2_col20 {
#             color:  black;
#             : ;
#             font-weight:  bold;
#         }    #T_3f6abb0c_987f_11ea_9f37_1065301e6a96row3_col0 {
#             color:  black;
#             : ;
#         }    #T_3f6abb0c_987f_11ea_9f37_1065301e6a96row3_col1 {
#             color:  black;
#             : ;
#         }    #T_3f6abb0c_987f_11ea_9f37_1065301e6a96row3_col2 {
#             color:  black;
#             : ;
#         }    #T_3f6abb0c_987f_11ea_9f37_1065301e6a96row3_col3 {
#             color:  black;
#             : ;
#         }    #T_3f6abb0c_987f_11ea_9f37_1065301e6a96row3_col4 {
#             color:  black;
#             : ;
#         }    #T_3f6abb0c_987f_11ea_9f37_1065301e6a96row3_col5 {
#             color:  black;
#             background-color:  gold;
#         }    #T_3f6abb0c_987f_11ea_9f37_1065301e6a96row3_col6 {
#             color:  black;
#             : ;
#         }    #T_3f6abb0c_987f_11ea_9f37_1065301e6a96row3_col7 {
